# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# spacy for lemmatization
import spacy

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

import pickle
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
from nltk.stem import WordNetLemmatizer
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b3f0ed331445> in <module>
#       5
#       6 # Gensim
# ----> 7 import gensim
#       8 import gensim.corpora as corpora
#       9 from gensim.utils import simple_preprocess
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\__init__.py in <module>
#       3 """
#       4
# ----> 5 from gensim import parsing, corpora, matutils, interfaces, models, similarities, summarization, utils  # noqa:F401
#       6 import logging
#       7
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\corpora\__init__.py in <module>
#       4
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       7
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\corpora\indexedcorpus.py in <module>
#      13 import numpy
#      14
# ---> 15 from gensim import interfaces, utils
#      16
#      17 logger = logging.getLogger(__name__)
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\interfaces.py in <module>
#      19 import logging
#      20
# ---> 21 from gensim import utils, matutils
#      22 from six.moves import range
#      23
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\matutils.py in <module>
#      19 import numpy as np
#      20 import scipy.sparse
# ---> 21 from scipy.stats import entropy
#      22 import scipy.linalg
#      23 from scipy.linalg.lapack import get_lapack_funcs
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\__init__.py in <module>
#     343 from __future__ import division, print_function, absolute_import
#     344
# --> 345 from .stats import *
#     346 from .distributions import *
#     347 from .morestats import *
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in <module>
#     169 import scipy.special as special
#     170 import scipy.linalg as linalg
# --> 171 from . import distributions
#     172 from . import mstats_basic
#     173 from ._distn_infrastructure import _lazywhere
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\distributions.py in <module>
#       8 from __future__ import division, print_function, absolute_import
#       9
# ---> 10 from ._distn_infrastructure import (entropy, rv_discrete, rv_continuous,
#      11                                     rv_frozen)
#      12
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in <module>
#      14 import warnings
#      15
# ---> 16 from scipy.misc import doccer
#      17 from ._distr_params import distcont, distdiscrete
#      18 from scipy._lib._util import check_random_state, _lazywhere, _lazyselect
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\misc\__init__.py in <module>
#      66 from numpy import who as _who, source as _source, info as _info
#      67 import numpy as np
# ---> 68 from scipy.interpolate._pade import pade as _pade
#      69 from scipy.special import (comb as _comb, logsumexp as _lsm,
#      70         factorial as _fact, factorial2 as _fact2, factorialk as _factk)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\interpolate\__init__.py in <module>
#     173 from __future__ import division, print_function, absolute_import
#     174
# --> 175 from .interpolate import *
#     176 from .fitpack import *
#     177
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\interpolate\interpolate.py in <module>
#      28 from . import _fitpack
#      29 from .polyint import _Interpolator1D
# ---> 30 from . import _ppoly
#      31 from .fitpack2 import RectBivariateSpline
#      32 from .interpnd import _ndim_coords_from_arrays
#
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py in parent(self)
#
# KeyboardInterrupt:

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])  # 불용어처리

#  빈도수 높은 키워드 처리
stop_words.extend([ 'from', 'subject', 're', 'edu', 'use', 'home', 'hunter', 'help', 'time', 'national', 'build', 'end', 'bid', 'cup', 'un', 'come', 'join', 'across','Italy', 'grind', 'asian', 'sa', 'miss', 'one', 'use', 'three', 'Darwin', 'vic', 'number', 'may', 'start', 'law', 'way', 'communities', 'order', 'check', 'major', 'india', 'focus', 'form', 'journalist', 'milk', 'nz', 'rank', 'cook', 'egypt', 'New', 'year', 'force', 'fail', 'dead', 'was', 'fruit', 'philippines','nick'])
stop_words.extend(['fire', 'new', 'world', 'boat', 'turn', 'around', 'well', 'Find', 'two', 'adelaide', 'first', 'make', 'body', 'probe', 'outback', 'baby', 'David', 'street', 'mass', 'hotel', 'say', 'open', 'go', 'welcome', 'announce', 'level', 'allow', 'highest','queensland', 'kill', 'crash', 'road', 'record', 'nt', 'hit', 'plane', 'toll', 'suspend', 'peninsula', 'afghan', 'recovery','man', 'perth', 'flood', 'people', 'still', 'supply', 'siege', 'spark', 'summer', 'Michael', 'ops', 'large', 'flash', 'view', 'attack', 'back', 'mine', 'deal', 'fan', 'celebrate', 'target', 'hill', 'party', 'reveal', 'terrorism', 'video', 'pressure', 'remember', 'korea', 'indian', 'millions', 'drill', 'country', 'hour', 'podcast', 'leaders', 'thursday', 'abbott', 'tony',  'shorten', 'sach', 'day', 'years', 'show', 'teen', 'heat', 'issue', 'free', 'australias', 'asbestos', 'compete','South', 'china', 'talk', 'appeal', 'labor', 'plant', 'peter', 'allegedly', 'begin', 'try', 'ice', 'native', 'alcohol', 'Australia', 'league', 'live', 'launch',  'benefit', 'update', 'stream', 'cabinet', 'document', 'bob','Test', 'drug', 'brisbane', 'british', 'double', 'ebola', 'Wa', 'research', 'expansion', 'ready', 'old', 'release', 'paper', 'see'])

# 그 아래에서  빈도수 높은 키워드 처리
stop_words.extend(['call',  'queensland', 'melbourne', 'perth', 'thousands', 'alert', 'reveal', 'spark', 'amid', 'australian',  'brisbane', 'western', 'high', 'fan', 'prepare', 'british', 'battle', 'beach', 'wa', 'take',  'box', 'could',  'search', 'black', 'michael', 'week','man', 'day' ,'country', 'new', 'old', 'test',  'force', 'release', 'miss','say', 'south', 'was','fire', 'victoria', 'build','australia', 'court','find', 'fall','mine', 'darwin', 'break', 'record', 'david', 'reflect', 'remember','adelaide', 'show'])

#stop_words

# %%
import pandas as pd
data = pd.read_csv('/Users/moon-il/Downloads/abcnews-date-text.csv', error_bad_lines=False);

# %%
data['publish_date'] = pd.to_datetime(data['publish_date'].astype(str), format = '%Y%m%d')

# %%
data['publish_date'] = pd.DatetimeIndex(data['publish_date']).year

# %%
data2 = data['headline_text']

#data2

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data['headline_text']))

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# %%
data_words_nostops = pd.Series(data_words_nostops)
data_lemmatized = data_words_nostops.apply(lambda x: [WordNetLemmatizer().lemmatize(word, pos='v') for word in x])

# %%
temp = data
temp['lemmatize'] = data_lemmatized
for i in range(15):
    globals()['trend{}'.format(i+2003)] = temp.loc[temp.publish_date == i+2003]

# %%
trend_list = [trend2003, trend2004, trend2005, trend2006, trend2007, trend2008, trend2009, trend2010, trend2011, trend2012, trend2013, trend2014, trend2015, trend2016, trend2017]

# %%
lemmatized = list(trend2015['lemmatize'])  # 2015년 트렌드
id2word = corpora.Dictionary(lemmatized)
texts = lemmatized
corpus = [id2word.doc2bow(text) for text in texts]

# %%
lemmatized = remove_stopwords(lemmatized)

# %%
id2word = corpora.Dictionary(lemmatized)
texts = lemmatized
corpus = [id2word.doc2bow(text) for text in texts]

# %%
#  최적의 토픽의 수는 50으로 결정!!


# 최적의 모델은?
p = 20
ntopics = 20
r = 100
c = 1000
    
lda_model1 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=ntopics,  # 이건 나중에 그래프로 판단해보자!!!
                                           random_state=r,
                                           update_every=1,
                                           chunksize=c,
                                           passes=p,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model1.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model1, texts=lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -18.118695390842145
#
# Coherence Score:  0.5042278412488306

# %%
# Print the Keyword in the 10 topics
#
pprint(lda_model1.print_topics(20))
doc_lda = lda_model1[corpus]
# Out:
# [(0,
#   '0.063*"state" + 0.058*"set" + 0.049*"port" + 0.046*"lead" + 0.030*"bring" + '
#   '0.030*"beat" + 0.029*"keep" + 0.025*"mark" + 0.024*"aboriginal" + '
#   '0.024*"rally"'),
#  (1,
#   '0.115*"christmas" + 0.043*"star" + 0.040*"family" + 0.037*"bushfire" + '
#   '0.030*"lose" + 0.029*"look" + 0.027*"trade" + 0.025*"land" + 0.023*"coach" '
#   '+ 0.021*"raid"'),
#  (2,
#   '0.058*"accuse" + 0.050*"work" + 0.047*"urge" + 0.046*"share" + '
#   '0.039*"children" + 0.034*"park" + 0.031*"run" + 0.030*"men" + '
#   '0.029*"damage" + 0.026*"sea"'),
#  (3,
#   '0.072*"council" + 0.065*"face" + 0.062*"death" + 0.060*"november" + '
#   '0.053*"hobart" + 0.040*"review" + 0.027*"drive" + 0.023*"wednesday" + '
#   '0.020*"drop" + 0.020*"offer"'),
#  (4,
#   '0.120*"sydney" + 0.104*"plan" + 0.050*"ban" + 0.040*"newcastle" + '
#   '0.031*"islamic" + 0.024*"burn" + 0.023*"central" + 0.023*"pm" + '
#   '0.020*"media" + 0.020*"game"'),
#  (5,
#   '0.058*"murder" + 0.056*"fund" + 0.046*"car" + 0.036*"return" + '
#   '0.033*"centre" + 0.032*"women" + 0.032*"need" + 0.032*"farm" + '
#   '0.031*"island" + 0.030*"guilty"'),
#  (6,
#   '0.067*"get" + 0.066*"former" + 0.046*"support" + 0.035*"award" + '
#   '0.031*"boost" + 0.029*"bill" + 0.029*"local" + 0.023*"clear" + 0.021*"long" '
#   '+ 0.021*"remain"'),
#  (7,
#   '0.091*"nsw" + 0.048*"school" + 0.043*"minister" + 0.032*"dog" + '
#   '0.031*"station" + 0.031*"cattle" + 0.028*"leave" + 0.025*"discuss" + '
#   '0.025*"tas" + 0.023*"export"'),
#  (8,
#   '0.075*"paris" + 0.055*"hospital" + 0.044*"war" + 0.043*"community" + '
#   '0.039*"final" + 0.030*"mount" + 0.028*"mayor" + 0.026*"steal" + '
#   '0.020*"despite" + 0.019*"honour"'),
#  (9,
#   '0.048*"tasmanian" + 0.046*"rise" + 0.041*"price" + 0.039*"top" + '
#   '0.033*"industry" + 0.031*"injure" + 0.030*"grandstand" + 0.030*"strike" + '
#   '0.027*"stab" + 0.025*"expect"'),
#  (10,
#   '0.111*"government" + 0.087*"warn" + 0.038*"head" + 0.038*"pay" + '
#   '0.027*"tour" + 0.025*"indies" + 0.025*"tree" + 0.020*"campaign" + '
#   '0.019*"deaths" + 0.017*"behind"'),
#  (11,
#   '0.087*"charge" + 0.067*"change" + 0.052*"woman" + 0.044*"climate" + '
#   '0.040*"near" + 0.037*"service" + 0.034*"violence" + 0.032*"cut" + '
#   '0.032*"fight" + 0.025*"continue"'),
#  (12,
#   '0.180*"police" + 0.054*"tasmania" + 0.051*"shoot" + 0.040*"group" + '
#   '0.039*"arrest" + 0.038*"assault" + 0.027*"workers" + 0.026*"syria" + '
#   '0.023*"investigate" + 0.022*"officer"'),
#  (13,
#   '0.084*"market" + 0.069*"water" + 0.060*"concern" + 0.044*"child" + '
#   '0.041*"trial" + 0.032*"question" + 0.032*"rule" + 0.028*"allege" + '
#   '0.027*"study" + 0.026*"cause"'),
#  (14,
#   '0.096*"win" + 0.083*"us" + 0.058*"north" + 0.042*"farmers" + 0.028*"air" + '
#   '0.028*"name" + 0.026*"food" + 0.024*"young" + 0.024*"second" + '
#   '0.024*"regional"'),
#  (15,
#   '0.074*"rural" + 0.045*"house" + 0.045*"report" + 0.044*"canberra" + '
#   '0.037*"train" + 0.036*"news" + 0.035*"job" + 0.029*"residents" + '
#   '0.029*"meet" + 0.029*"city"'),
#  (16,
#   '0.089*"west" + 0.064*"health" + 0.058*"claim" + 0.051*"season" + '
#   '0.039*"ahead" + 0.034*"action" + 0.025*"northern" + 0.023*"highway" + '
#   '0.022*"best" + 0.021*"speak"'),
#  (17,
#   '0.054*"die" + 0.053*"jail" + 0.040*"act" + 0.038*"big" + 0.035*"victorian" '
#   '+ 0.034*"abuse" + 0.032*"power" + 0.031*"future" + 0.028*"students" + '
#   '0.026*"commission"'),
#  (18,
#   '0.068*"qld" + 0.040*"give" + 0.039*"close" + 0.034*"move" + 0.031*"want" + '
#   '0.031*"rat" + 0.029*"john" + 0.028*"hold" + 0.028*"mp" + 0.027*"five"'),
#  (19,
#   '0.099*"coast" + 0.057*"png" + 0.051*"gold" + 0.039*"premier" + 0.039*"sex" '
#   '+ 0.036*"cricket" + 0.032*"rescue" + 0.030*"parliament" + 0.029*"chief" + '
#   '0.025*"election"')]

# %%
#  최적의 토픽의 수는 50으로 결정!!


# 최적의 모델은?
p = 20
ntopics = 20
r = 100
c = 5000
    
lda_model2 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=ntopics,  # 이건 나중에 그래프로 판단해보자!!!
                                           random_state=r,
                                           update_every=1,
                                           chunksize=c,
                                           passes=p,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model2.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model2, texts=lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -12.894645477175882
#
# Coherence Score:  0.4461369789148574

# %%
# Print the Keyword in the 10 topics
#
pprint(lda_model2.print_topics(20))
doc_lda = lda_model1[corpus]
# Out:
# [(0,
#   '0.083*"win" + 0.033*"port" + 0.026*"beat" + 0.024*"push" + 0.020*"award" + '
#   '0.018*"bring" + 0.018*"president" + 0.018*"game" + 0.017*"rescue" + '
#   '0.016*"club"'),
#  (1,
#   '0.042*"north" + 0.033*"job" + 0.032*"cut" + 0.027*"afl" + 0.027*"lose" + '
#   '0.021*"land" + 0.021*"million" + 0.021*"tas" + 0.018*"question" + '
#   '0.015*"defend"'),
#  (2,
#   '0.061*"market" + 0.037*"share" + 0.028*"children" + 0.028*"grandstand" + '
#   '0.021*"wednesday" + 0.020*"drum" + 0.020*"damage" + 0.020*"asylum" + '
#   '0.019*"friday" + 0.019*"great"'),
#  (3,
#   '0.056*"christmas" + 0.039*"tasmania" + 0.031*"november" + 0.030*"hobart" + '
#   '0.026*"women" + 0.022*"hear" + 0.019*"yo" + 0.018*"anti" + '
#   '0.016*"parliament" + 0.016*"fish"'),
#  (4,
#   '0.066*"sydney" + 0.053*"change" + 0.037*"health" + 0.031*"ban" + '
#   '0.031*"hospital" + 0.027*"climate" + 0.026*"paris" + 0.023*"turnbull" + '
#   '0.020*"interview" + 0.020*"nrl"'),
#  (5,
#   '0.062*"us" + 0.031*"lead" + 0.030*"return" + 0.025*"island" + '
#   '0.025*"continue" + 0.023*"case" + 0.022*"pacific" + 0.022*"tell" + '
#   '0.022*"inquiry" + 0.020*"september"'),
#  (6,
#   '0.072*"charge" + 0.044*"face" + 0.042*"murder" + 0.040*"death" + '
#   '0.031*"accuse" + 0.030*"claim" + 0.028*"drought" + 0.025*"newcastle" + '
#   '0.025*"star" + 0.018*"allege"'),
#  (7,
#   '0.087*"nsw" + 0.080*"rural" + 0.036*"news" + 0.032*"farmers" + '
#   '0.029*"cattle" + 0.025*"station" + 0.021*"students" + 0.021*"food" + '
#   '0.018*"chief" + 0.018*"tuesday"'),
#  (8,
#   '0.046*"die" + 0.032*"season" + 0.028*"industry" + 0.027*"war" + '
#   '0.025*"storm" + 0.021*"name" + 0.020*"coach" + 0.018*"mayor" + '
#   '0.018*"festival" + 0.017*"mark"'),
#  (9,
#   '0.057*"plan" + 0.033*"house" + 0.032*"water" + 0.027*"rise" + 0.026*"price" '
#   '+ 0.020*"public" + 0.016*"fear" + 0.016*"action" + 0.016*"bill" + '
#   '0.016*"company"'),
#  (10,
#   '0.048*"council" + 0.045*"warn" + 0.028*"urge" + 0.028*"group" + '
#   '0.027*"support" + 0.025*"review" + 0.025*"meet" + 0.023*"residents" + '
#   '0.021*"seek" + 0.020*"green"'),
#  (11,
#   '0.046*"state" + 0.035*"train" + 0.034*"fight" + 0.033*"family" + '
#   '0.025*"ahead" + 0.023*"race" + 0.022*"islamic" + 0.021*"discuss" + '
#   '0.021*"program" + 0.019*"raise"'),
#  (12,
#   '0.101*"police" + 0.037*"fund" + 0.037*"west" + 0.036*"woman" + 0.031*"get" '
#   '+ 0.030*"car" + 0.026*"shoot" + 0.024*"arrest" + 0.018*"park" + '
#   '0.015*"workers"'),
#  (13,
#   '0.037*"tasmanian" + 0.037*"concern" + 0.032*"work" + 0.030*"centre" + '
#   '0.028*"community" + 0.028*"give" + 0.028*"need" + 0.027*"dog" + '
#   '0.024*"trade" + 0.020*"rule"'),
#  (14,
#   '0.043*"school" + 0.029*"indigenous" + 0.027*"big" + 0.025*"run" + '
#   '0.023*"injure" + 0.021*"air" + 0.020*"young" + 0.017*"rain" + 0.017*"put" + '
#   '0.016*"weather"'),
#  (15,
#   '0.034*"december" + 0.031*"jail" + 0.031*"near" + 0.028*"farm" + '
#   '0.024*"close" + 0.023*"trial" + 0.022*"city" + 0.021*"life" + '
#   '0.021*"strike" + 0.019*"bushfire"'),
#  (16,
#   '0.062*"qld" + 0.044*"minister" + 0.041*"service" + 0.033*"top" + '
#   '0.029*"pay" + 0.023*"northern" + 0.021*"challenge" + 0.020*"study" + '
#   '0.019*"tax" + 0.017*"doctor"'),
#  (17,
#   '0.035*"violence" + 0.031*"rugby" + 0.026*"domestic" + 0.026*"hold" + '
#   '0.025*"future" + 0.024*"royal" + 0.024*"rat" + 0.023*"look" + '
#   '0.023*"commission" + 0.022*"river"'),
#  (18,
#   '0.063*"government" + 0.037*"report" + 0.035*"former" + 0.027*"act" + '
#   '0.026*"png" + 0.024*"child" + 0.024*"federal" + 0.022*"abuse" + 0.021*"sex" '
#   '+ 0.021*"move"'),
#  (19,
#   '0.050*"coast" + 0.040*"canberra" + 0.034*"set" + 0.028*"gold" + '
#   '0.028*"final" + 0.022*"guilty" + 0.022*"head" + 0.022*"leave" + '
#   '0.022*"power" + 0.018*"premier"')]

# %%
#  최적의 토픽의 수는 50으로 결정!!


# 최적의 모델은?
p = 20
ntopics = 40
r = 100
c = 1000
    
lda_model3 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=ntopics,  # 이건 나중에 그래프로 판단해보자!!!
                                           random_state=r,
                                           update_every=1,
                                           chunksize=c,
                                           passes=p,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model3.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model3, texts=lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -28.377202973874052
#
# Coherence Score:  0.5810693562016778

# %%
# Print the Keyword in the 10 topics
#
pprint(lda_model3.print_topics(40))
doc_lda = lda_model1[corpus]
# Out:
# [(0,
#   '0.123*"state" + 0.094*"port" + 0.055*"save" + 0.053*"allege" + 0.048*"risk" '
#   '+ 0.046*"aboriginal" + 0.046*"rally" + 0.041*"hand" + 0.041*"mother" + '
#   '0.040*"escape"'),
#  (1,
#   '0.220*"christmas" + 0.058*"lose" + 0.057*"future" + 0.050*"hold" + '
#   '0.047*"anti" + 0.040*"rain" + 0.037*"crop" + 0.035*"game" + '
#   '0.034*"emergency" + 0.031*"harvest"'),
#  (2,
#   '0.142*"warn" + 0.088*"star" + 0.084*"job" + 0.073*"big" + 0.067*"children" '
#   '+ 0.044*"sea" + 0.035*"capital" + 0.034*"gas" + 0.031*"tip" + '
#   '0.024*"night"'),
#  (3,
#   '0.134*"market" + 0.089*"rise" + 0.082*"cut" + 0.078*"review" + '
#   '0.051*"boost" + 0.045*"business" + 0.040*"security" + 0.038*"russian" + '
#   '0.034*"remain" + 0.033*"oil"'),
#  (4,
#   '0.137*"health" + 0.100*"assault" + 0.059*"challenge" + 0.055*"right" + '
#   '0.054*"bash" + 0.049*"jet" + 0.048*"consider" + 0.036*"confirm" + '
#   '0.028*"smith" + 0.024*"champion"'),
#  (5,
#   '0.082*"industry" + 0.068*"cricket" + 0.053*"play" + 0.049*"delay" + '
#   '0.048*"girl" + 0.040*"international" + 0.038*"investigation" + '
#   '0.033*"reporter" + 0.031*"yacht" + 0.031*"destroy"'),
#  (6,
#   '0.094*"newcastle" + 0.092*"close" + 0.055*"parliament" + 0.048*"shark" + '
#   '0.045*"team" + 0.034*"threat" + 0.033*"mps" + 0.033*"refugee" + '
#   '0.031*"livestock" + 0.028*"camp"'),
#  (7,
#   '0.086*"final" + 0.079*"grandstand" + 0.066*"beat" + 0.051*"truck" + '
#   '0.050*"asylum" + 0.045*"part" + 0.029*"declare" + 0.028*"reduce" + '
#   '0.027*"proposal" + 0.026*"seekers"'),
#  (8,
#   '0.205*"council" + 0.105*"farm" + 0.063*"tour" + 0.058*"tree" + '
#   '0.038*"dollar" + 0.035*"aussie" + 0.024*"kangaroo" + 0.021*"locals" + '
#   '0.017*"horticulture" + 0.017*"event"'),
#  (9,
#   '0.319*"police" + 0.085*"ban" + 0.070*"arrest" + 0.054*"driver" + '
#   '0.047*"run" + 0.047*"four" + 0.040*"chinese" + 0.036*"increase" + '
#   '0.031*"hop" + 0.031*"bail"'),
#  (10,
#   '0.080*"premier" + 0.071*"question" + 0.066*"festival" + 0.058*"indies" + '
#   '0.054*"gun" + 0.040*"behind" + 0.034*"politics" + 0.033*"stock" + '
#   '0.033*"seize" + 0.032*"attempt"'),
#  (11,
#   '0.208*"charge" + 0.125*"woman" + 0.124*"murder" + 0.057*"injure" + '
#   '0.048*"yo" + 0.033*"stand" + 0.031*"townsville" + 0.030*"indonesia" + '
#   '0.029*"clean" + 0.025*"decision"'),
#  (12,
#   '0.184*"paris" + 0.085*"push" + 0.066*"officer" + 0.056*"link" + '
#   '0.049*"despite" + 0.047*"honour" + 0.039*"grand" + 0.036*"fifa" + '
#   '0.032*"third" + 0.026*"hail"'),
#  (13,
#   '0.137*"school" + 0.115*"work" + 0.061*"second" + 0.051*"media" + '
#   '0.042*"volunteer" + 0.039*"staff" + 0.037*"social" + 0.028*"round" + '
#   '0.028*"soldier" + 0.026*"vow"'),
#  (14,
#   '0.113*"north" + 0.074*"meet" + 0.064*"pay" + 0.058*"trade" + 0.056*"drive" '
#   '+ 0.055*"air" + 0.051*"export" + 0.049*"local" + 0.033*"interview" + '
#   '0.024*"chris"'),
#  (15,
#   '0.105*"report" + 0.097*"accuse" + 0.092*"concern" + 0.069*"residents" + '
#   '0.064*"trial" + 0.057*"green" + 0.054*"tell" + 0.048*"raise" + 0.041*"cost" '
#   '+ 0.040*"vote"'),
#  (16,
#   '0.201*"win" + 0.089*"price" + 0.072*"cattle" + 0.068*"head" + 0.068*"race" '
#   '+ 0.044*"northern" + 0.041*"sale" + 0.040*"best" + 0.026*"bay" + '
#   '0.024*"territory"'),
#  (17,
#   '0.120*"claim" + 0.073*"sex" + 0.069*"students" + 0.060*"coach" + '
#   '0.053*"rate" + 0.046*"catch" + 0.045*"bank" + 0.027*"unveil" + '
#   '0.027*"speed" + 0.025*"allegations"'),
#  (18,
#   '0.165*"government" + 0.111*"death" + 0.099*"former" + 0.065*"community" + '
#   '0.065*"island" + 0.050*"john" + 0.047*"tas" + 0.042*"protest" + '
#   '0.029*"sport" + 0.022*"upgrade"'),
#  (19,
#   '0.173*"plan" + 0.091*"jail" + 0.078*"train" + 0.072*"season" + '
#   '0.065*"women" + 0.037*"line" + 0.036*"track" + 0.032*"defend" + '
#   '0.030*"bendigo" + 0.026*"france"'),
#  (20,
#   '0.113*"die" + 0.112*"car" + 0.109*"near" + 0.063*"case" + 0.057*"mp" + '
#   '0.039*"threaten" + 0.038*"age" + 0.037*"doctor" + 0.035*"site" + '
#   '0.034*"defence"'),
#  (21,
#   '0.079*"family" + 0.076*"share" + 0.075*"farmers" + 0.059*"power" + '
#   '0.056*"rat" + 0.051*"discuss" + 0.048*"east" + 0.043*"burn" + '
#   '0.036*"follow" + 0.035*"rail"'),
#  (22,
#   '0.092*"give" + 0.066*"river" + 0.059*"keep" + 0.041*"unite" + '
#   '0.035*"become" + 0.034*"st" + 0.034*"online" + 0.030*"forecast" + '
#   '0.030*"struggle" + 0.030*"drown"'),
#  (23,
#   '0.239*"rural" + 0.088*"station" + 0.079*"islamic" + 0.058*"central" + '
#   '0.044*"bomb" + 0.043*"impact" + 0.037*"sugar" + 0.035*"result" + '
#   '0.030*"crowd" + 0.029*"councils"'),
#  (24,
#   '0.206*"sydney" + 0.087*"set" + 0.059*"move" + 0.053*"park" + 0.053*"strike" '
#   '+ 0.040*"president" + 0.036*"drop" + 0.035*"offer" + 0.026*"french" + '
#   '0.025*"eve"'),
#  (25,
#   '0.116*"need" + 0.077*"mount" + 0.072*"investigate" + 0.069*"steal" + '
#   '0.061*"laws" + 0.043*"youth" + 0.043*"early" + 0.042*"good" + '
#   '0.033*"andrew" + 0.030*"son"'),
#  (26,
#   '0.125*"face" + 0.107*"get" + 0.066*"public" + 0.058*"want" + 0.046*"bill" + '
#   '0.045*"wednesday" + 0.037*"clear" + 0.031*"history" + 0.031*"deaths" + '
#   '0.029*"pass"'),
#  (27,
#   '0.177*"nsw" + 0.131*"west" + 0.083*"minister" + 0.046*"great" + '
#   '0.042*"young" + 0.041*"opposition" + 0.040*"study" + 0.030*"speak" + '
#   '0.030*"cancer" + 0.028*"leader"'),
#  (28,
#   '0.133*"house" + 0.098*"group" + 0.062*"suspect" + 0.057*"rescue" + '
#   '0.040*"sell" + 0.039*"investment" + 0.034*"ship" + 0.029*"lift" + '
#   '0.027*"victim" + 0.024*"loss"'),
#  (29,
#   '0.107*"qld" + 0.090*"water" + 0.062*"support" + 0.056*"dog" + 0.055*"abuse" '
#   '+ 0.051*"life" + 0.049*"leave" + 0.042*"commission" + 0.041*"royal" + '
#   '0.030*"election"'),
#  (30,
#   '0.123*"news" + 0.072*"fear" + 0.072*"men" + 0.072*"five" + 0.055*"friday" + '
#   '0.048*"long" + 0.046*"exchange" + 0.036*"days" + 0.026*"describe" + '
#   '0.023*"killer"'),
#  (31,
#   '0.109*"tasmania" + 0.076*"bushfire" + 0.068*"victorian" + 0.063*"ahead" + '
#   '0.049*"food" + 0.047*"sign" + 0.043*"pm" + 0.041*"put" + 0.041*"stop" + '
#   '0.038*"reject"'),
#  (32,
#   '0.106*"canberra" + 0.093*"service" + 0.082*"png" + 0.071*"city" + '
#   '0.064*"continue" + 0.048*"expect" + 0.041*"point" + 0.041*"fish" + '
#   '0.036*"victims" + 0.033*"demand"'),
#  (33,
#   '0.075*"name" + 0.072*"land" + 0.060*"weather" + 0.059*"mark" + 0.047*"boss" '
#   '+ 0.046*"global" + 0.043*"step" + 0.041*"create" + 0.035*"arm" + '
#   '0.033*"fuel"'),
#  (34,
#   '0.153*"us" + 0.100*"shoot" + 0.092*"tasmanian" + 0.076*"act" + '
#   '0.040*"syrian" + 0.025*"scientists" + 0.025*"crew" + 0.024*"policy" + '
#   '0.023*"receive" + 0.023*"interest"'),
#  (35,
#   '0.102*"hospital" + 0.091*"return" + 0.090*"urge" + 0.086*"top" + '
#   '0.081*"war" + 0.046*"zealand" + 0.044*"condition" + 0.037*"spot" + '
#   '0.037*"post" + 0.032*"crime"'),
#  (36,
#   '0.092*"fight" + 0.085*"lead" + 0.077*"guilty" + 0.052*"afl" + '
#   '0.051*"regional" + 0.047*"chief" + 0.047*"safety" + 0.045*"plead" + '
#   '0.030*"political" + 0.029*"cairns"'),
#  (37,
#   '0.115*"november" + 0.074*"centre" + 0.058*"million" + 0.058*"look" + '
#   '0.049*"damage" + 0.046*"mayor" + 0.041*"cause" + 0.040*"visit" + '
#   '0.037*"red" + 0.031*"russia"'),
#  (38,
#   '0.152*"coast" + 0.089*"violence" + 0.078*"gold" + 0.057*"sentence" + '
#   '0.055*"workers" + 0.054*"syria" + 0.041*"tax" + 0.033*"six" + '
#   '0.026*"england" + 0.023*"aid"'),
#  (39,
#   '0.138*"change" + 0.091*"climate" + 0.084*"hobart" + 0.046*"award" + '
#   '0.044*"coal" + 0.041*"hear" + 0.041*"rule" + 0.032*"monday" + 0.032*"deny" '
#   '+ 0.030*"legal"')]

# %%
#  최적의 토픽의 수는 50으로 결정!!


# 최적의 모델은?
p = 20
ntopics = 40
r = 100
c = 5000
    
lda_model4 = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=ntopics,  # 이건 나중에 그래프로 판단해보자!!!
                                           random_state=r,
                                           update_every=1,
                                           chunksize=c,
                                           passes=p,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model4.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model4, texts=lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -17.491733861929415
#
# Coherence Score:  0.5597804997436081

# %%
# Print the Keyword in the 10 topics
#
pprint(lda_model4.print_topics(40))
#doc_lda = lda_model1[corpus]
# Out:
# [(0,
#   '0.076*"ban" + 0.075*"service" + 0.067*"port" + 0.062*"newcastle" + '
#   '0.045*"allege" + 0.044*"september" + 0.034*"tax" + 0.033*"rally" + '
#   '0.031*"mother" + 0.024*"clash"'),
#  (1,
#   '0.080*"star" + 0.077*"meet" + 0.048*"game" + 0.044*"rain" + 0.035*"harvest" '
#   '+ 0.030*"threat" + 0.025*"likely" + 0.023*"night" + 0.020*"know" + '
#   '0.019*"mango"'),
#  (2,
#   '0.065*"job" + 0.064*"cut" + 0.050*"island" + 0.039*"business" + '
#   '0.034*"protest" + 0.031*"capital" + 0.029*"students" + 0.025*"indonesia" + '
#   '0.025*"international" + 0.024*"bash"'),
#  (3,
#   '0.072*"house" + 0.062*"concern" + 0.047*"give" + 0.040*"trade" + '
#   '0.037*"future" + 0.031*"raise" + 0.029*"laws" + 0.027*"inquest" + '
#   '0.027*"parliament" + 0.026*"consider"'),
#  (4,
#   '0.103*"west" + 0.051*"victorian" + 0.047*"storm" + 0.038*"young" + '
#   '0.038*"east" + 0.035*"opposition" + 0.032*"team" + 0.030*"weather" + '
#   '0.024*"step" + 0.024*"confirm"'),
#  (5,
#   '0.106*"market" + 0.065*"share" + 0.050*"industry" + 0.039*"food" + '
#   '0.037*"yo" + 0.033*"expect" + 0.033*"fatal" + 0.030*"delay" + 0.026*"girl" '
#   '+ 0.020*"scott"'),
#  (6,
#   '0.062*"close" + 0.048*"tas" + 0.031*"long" + 0.029*"jam" + 0.026*"impact" + '
#   '0.025*"refugee" + 0.023*"result" + 0.022*"fifa" + 0.021*"zone" + '
#   '0.017*"rape"'),
#  (7,
#   '0.059*"work" + 0.056*"hobart" + 0.046*"grandstand" + 0.044*"seek" + '
#   '0.043*"news" + 0.039*"rat" + 0.039*"fear" + 0.034*"shark" + 0.031*"bank" + '
#   '0.029*"safety"'),
#  (8,
#   '0.075*"car" + 0.058*"farm" + 0.046*"park" + 0.045*"pay" + 0.041*"arrest" + '
#   '0.039*"million" + 0.036*"five" + 0.029*"fiji" + 0.029*"link" + '
#   '0.028*"fish"'),
#  (9,
#   '0.103*"coast" + 0.092*"warn" + 0.058*"gold" + 0.046*"residents" + '
#   '0.043*"strike" + 0.031*"central" + 0.031*"steal" + 0.027*"burn" + '
#   '0.025*"gun" + 0.024*"follow"'),
#  (10,
#   '0.139*"nsw" + 0.073*"state" + 0.038*"green" + 0.035*"islamic" + '
#   '0.034*"premier" + 0.034*"john" + 0.033*"coal" + 0.028*"vote" + 0.026*"stop" '
#   '+ 0.023*"threaten"'),
#  (11,
#   '0.124*"charge" + 0.074*"face" + 0.060*"former" + 0.058*"december" + '
#   '0.045*"murder" + 0.042*"child" + 0.041*"rugby" + 0.039*"abuse" + '
#   '0.037*"sex" + 0.030*"sign"'),
#  (12,
#   '0.220*"police" + 0.047*"paris" + 0.033*"four" + 0.032*"union" + '
#   '0.029*"investigate" + 0.028*"cricket" + 0.027*"officer" + 0.026*"cost" + '
#   '0.024*"raid" + 0.023*"grand"'),
#  (13,
#   '0.049*"bushfire" + 0.042*"second" + 0.041*"pm" + 0.040*"keep" + '
#   '0.032*"media" + 0.028*"ash" + 0.025*"social" + 0.024*"chris" + '
#   '0.023*"crisis" + 0.021*"govt"'),
#  (14,
#   '0.079*"set" + 0.055*"dog" + 0.053*"head" + 0.048*"run" + 0.031*"energy" + '
#   '0.030*"sale" + 0.025*"wild" + 0.024*"history" + 0.023*"part" + '
#   '0.022*"next"'),
#  (15,
#   '0.080*"jail" + 0.073*"accuse" + 0.071*"hospital" + 0.050*"children" + '
#   '0.037*"stab" + 0.025*"highway" + 0.023*"townsville" + 0.021*"murder" + '
#   '0.019*"cairns" + 0.019*"upgrade"'),
#  (16,
#   '0.096*"rural" + 0.082*"qld" + 0.061*"school" + 0.049*"violence" + '
#   '0.048*"png" + 0.043*"top" + 0.036*"domestic" + 0.035*"afl" + 0.032*"action" '
#   '+ 0.017*"reporter"'),
#  (17,
#   '0.144*"us" + 0.043*"tour" + 0.043*"coach" + 0.027*"control" + '
#   '0.026*"france" + 0.026*"grow" + 0.024*"andrew" + 0.022*"russia" + '
#   '0.022*"arm" + 0.017*"among"'),
#  (18,
#   '0.100*"christmas" + 0.075*"health" + 0.059*"drought" + 0.050*"community" + '
#   '0.041*"hold" + 0.039*"inquiry" + 0.038*"royal" + 0.036*"discuss" + '
#   '0.036*"commission" + 0.027*"mental"'),
#  (19,
#   '0.163*"win" + 0.037*"point" + 0.033*"rail" + 0.032*"track" + 0.029*"line" + '
#   '0.025*"title" + 0.024*"development" + 0.020*"ex" + 0.019*"film" + '
#   '0.018*"bridge"'),
#  (20,
#   '0.050*"big" + 0.045*"tell" + 0.044*"mp" + 0.036*"damage" + 0.036*"hear" + '
#   '0.033*"increase" + 0.033*"risk" + 0.031*"cause" + 0.029*"right" + '
#   '0.025*"defence"'),
#  (21,
#   '0.070*"family" + 0.065*"support" + 0.046*"injure" + 0.045*"company" + '
#   '0.032*"doctor" + 0.028*"st" + 0.026*"russian" + 0.026*"key" + 0.025*"oil" + '
#   '0.023*"mps"'),
#  (22,
#   '0.099*"canberra" + 0.083*"minister" + 0.074*"north" + 0.054*"move" + '
#   '0.042*"river" + 0.042*"air" + 0.032*"bomb" + 0.027*"mount" + 0.027*"boss" + '
#   '0.021*"suicide"'),
#  (23,
#   '0.078*"rise" + 0.046*"bill" + 0.041*"question" + 0.040*"anti" + '
#   '0.038*"president" + 0.033*"rate" + 0.032*"visit" + 0.028*"debate" + '
#   '0.024*"sugar" + 0.023*"drink"'),
#  (24,
#   '0.097*"water" + 0.064*"cattle" + 0.054*"interview" + 0.045*"export" + '
#   '0.036*"club" + 0.033*"condition" + 0.030*"dairy" + 0.030*"beef" + '
#   '0.030*"mackay" + 0.028*"shire"'),
#  (25,
#   '0.057*"group" + 0.050*"need" + 0.045*"war" + 0.041*"pacific" + '
#   '0.036*"northern" + 0.033*"drum" + 0.032*"bring" + 0.027*"august" + '
#   '0.026*"creek" + 0.025*"sell"'),
#  (26,
#   '0.084*"get" + 0.063*"fight" + 0.048*"leave" + 0.031*"zealand" + '
#   '0.027*"emergency" + 0.025*"jet" + 0.023*"site" + 0.023*"ceo" + '
#   '0.022*"reform" + 0.020*"grant"'),
#  (27,
#   '0.100*"government" + 0.098*"plan" + 0.071*"council" + 0.067*"fund" + '
#   '0.042*"urge" + 0.037*"federal" + 0.037*"review" + 0.032*"power" + '
#   '0.023*"chief" + 0.019*"hop"'),
#  (28,
#   '0.077*"tasmanian" + 0.075*"shoot" + 0.053*"continue" + 0.049*"price" + '
#   '0.044*"workers" + 0.031*"defend" + 0.031*"reject" + 0.025*"six" + '
#   '0.023*"town" + 0.020*"tackle"'),
#  (29,
#   '0.068*"die" + 0.062*"tasmania" + 0.047*"centre" + 0.043*"lose" + '
#   '0.038*"life" + 0.037*"push" + 0.033*"project" + 0.028*"save" + '
#   '0.026*"great" + 0.025*"sea"'),
#  (30,
#   '0.049*"station" + 0.049*"case" + 0.041*"program" + 0.040*"light" + '
#   '0.038*"wednesday" + 0.036*"suspect" + 0.035*"friday" + 0.033*"monday" + '
#   '0.027*"despite" + 0.025*"post"'),
#  (31,
#   '0.064*"final" + 0.054*"public" + 0.051*"beat" + 0.050*"want" + 0.045*"race" '
#   '+ 0.035*"mayor" + 0.032*"put" + 0.024*"extend" + 0.023*"become" + '
#   '0.021*"reach"'),
#  (32,
#   '0.131*"sydney" + 0.086*"woman" + 0.044*"guilty" + 0.040*"nrl" + '
#   '0.034*"name" + 0.028*"plead" + 0.023*"demand" + 0.021*"investment" + '
#   '0.018*"avoid" + 0.018*"shop"'),
#  (33,
#   '0.094*"death" + 0.089*"report" + 0.052*"trial" + 0.044*"sentence" + '
#   '0.035*"chinese" + 0.029*"stand" + 0.027*"escape" + 0.025*"best" + '
#   '0.019*"sheep" + 0.017*"sales"'),
#  (34,
#   '0.066*"near" + 0.061*"act" + 0.057*"return" + 0.038*"boost" + 0.032*"local" '
#   '+ 0.029*"deny" + 0.027*"care" + 0.027*"syrian" + 0.026*"unite" + '
#   '0.024*"bail"'),
#  (35,
#   '0.076*"claim" + 0.065*"season" + 0.047*"land" + 0.044*"rule" + '
#   '0.039*"syria" + 0.033*"aboriginal" + 0.033*"offer" + 0.029*"clear" + '
#   '0.020*"nauru" + 0.018*"gay"'),
#  (36,
#   '0.059*"indigenous" + 0.053*"ahead" + 0.039*"challenge" + 0.038*"regional" + '
#   '0.035*"crop" + 0.032*"hunt" + 0.032*"campaign" + 0.023*"victory" + '
#   '0.019*"bishop" + 0.018*"flag"'),
#  (37,
#   '0.056*"november" + 0.055*"farmers" + 0.046*"city" + 0.038*"look" + '
#   '0.037*"driver" + 0.035*"budget" + 0.033*"drive" + 0.031*"study" + '
#   '0.030*"rescue" + 0.027*"truck"'),
#  (38,
#   '0.069*"turnbull" + 0.068*"women" + 0.042*"mark" + 0.039*"assault" + '
#   '0.029*"dump" + 0.027*"malcolm" + 0.025*"match" + 0.022*"university" + '
#   '0.022*"politics" + 0.020*"liberal"'),
#  (39,
#   '0.112*"change" + 0.063*"train" + 0.059*"lead" + 0.057*"climate" + '
#   '0.036*"award" + 0.033*"play" + 0.032*"tuesday" + 0.031*"festival" + '
#   '0.024*"fly" + 0.024*"hand"')]
